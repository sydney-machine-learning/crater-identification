# %%
import os
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix,precision_score, recall_score, f1_score

# %% [markdown]
# Read YOLO data & process

# %%
# DATA PATH
path = 'final_dataset_withnon'
train_img_path = os.path.join(path, 'images', 'train')
train_lbl_path = os.path.join(path, 'labels', 'train')

valid_img_path = os.path.join(path, 'images', 'val')
valid_lbl_path = os.path.join(path, 'labels', 'val')

test_img_path = os.path.join(path, 'images', 'test')
test_lbl_path = os.path.join(path, 'labels', 'test')

IMG_SIZE = 128
NUM_CLASSES = 4

# path to save processed images
processed_path = os.path.join(path, 'processed')
os.makedirs(processed_path, exist_ok=True)

# %%
# process a dataset by extracting craters from images based on YOLO-format labels and saving them in class-specific directories. 
def process_dataset(img_dir, lbl_dir, output_dir):
    for img_file in os.listdir(img_dir):
        if not img_file.endswith('.jpg'):
            continue # skip non-image files
            
        # Get the corresponding label file
        base_name = os.path.splitext(img_file)[0]
        lbl_file = os.path.join(lbl_dir, f"{base_name}.txt")
        
        # Process single image
        img = Image.open(os.path.join(img_dir, img_file))
        img_w, img_h = img.size
        
        with open(lbl_file, 'r') as f:
            for idx, line in enumerate(f.readlines()):
                class_id, xc, yc, w, h = map(float, line.strip().split())
                # Ensure image bounds
                x1 = int((xc - w/2) * img_w)
                y1 = int((yc - h/2) * img_h)
                x2 = int((xc + w/2) * img_w)
                y2 = int((yc + h/2) * img_h)
                                
                x1, y1 = max(0, x1), max(0, y1)
                x2, y2 = min(img_w, x2), min(img_h, y2)
                
                # Crop the crater and resize it
                crater = img.crop((x1, y1, x2, y2))
                crater = crater.resize((IMG_SIZE, IMG_SIZE), Image.Resampling.LANCZOS)
                # save
                class_dir = os.path.join(output_dir, str(int(class_id)))
                os.makedirs(class_dir, exist_ok=True)
                crater.save(os.path.join(class_dir, f"{base_name}_{idx}.jpg"))

# process all dataset
process_dataset(train_img_path, train_lbl_path, os.path.join(processed_path, 'train'))
process_dataset(valid_img_path, valid_lbl_path, os.path.join(processed_path, 'val'))
process_dataset(test_img_path, test_lbl_path, os.path.join(processed_path, 'test'))

# %%
# define a PyTorch dataset for loading crater images and their corresponding labels.
class CraterDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data = []
        self.transform = transform
        
        for class_id in range(NUM_CLASSES):
            class_dir = os.path.join(data_dir, str(class_id))
            for img_file in os.listdir(class_dir):
                self.data.append((os.path.join(class_dir, img_file), class_id))
                
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_path, label = self.data[idx]
        img = Image.open(img_path).convert('RGB') 
        
        if self.transform:
            img = self.transform(img)
            
        return img, label

# %%
# Define data enhancement
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Loading data from category folder (using grayscale mode!)
train_generator = train_datagen.flow_from_directory(
    os.path.join(processed_path, 'train'),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale' # (using grayscale mode!)
)
val_generator = train_datagen.flow_from_directory(
    os.path.join(processed_path, 'val'),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale'# (using grayscale mode!)
)
# Out:
# Found 1880 images belonging to 4 classes.
# Found 413 images belonging to 4 classes.

# %%
# test data
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    os.path.join(processed_path, 'test'),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    class_mode='categorical', 
    shuffle=False,
    color_mode='grayscale'
)
# Out:
# Found 872 images belonging to 4 classes.

# %% [markdown]
# Model Test & Prediction

# %% [markdown]
# CNN Model

# %%
def create_model():
    model = Sequential()
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
        MaxPooling2D((2,2)),

        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D((2,2)),

        Conv2D(128, (3,3), activation='relu'),
        MaxPooling2D((2,2)),

        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Parameter settings
NUM_RUNS = 30
class_names = list(test_generator.class_indices.keys())

# Initialize storage structure for metrics
metrics = {
    'classes': {cls: {'precision': [], 'recall': [], 'f1': []} for cls in class_names},
    'macro_avg': {'precision': [], 'recall': [], 'f1': []},
    'weighted_avg': {'precision': [], 'recall': [], 'f1': []},
    'accuracy': []
}

for run in range(NUM_RUNS):
    print(f"\n=========== Training Run {run+1}/{NUM_RUNS} ===========")
    
    # Reset model and random seeds before each training run
    tf.keras.backend.clear_session()
    np.random.seed(run)
    tf.random.set_seed(run)
    
    # Create a new model
    model = create_model()
    
    # Define callbacks
    checkpoint = ModelCheckpoint('best_model.keras', 
                                monitor='val_loss',
                                save_best_only=True,
                                mode='min',
                                verbose=0)
    early_stop = EarlyStopping(monitor='val_loss',
                              patience=5,
                              restore_best_weights=True)
    
    # Train the model
    model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        callbacks=[checkpoint, early_stop],
        verbose=1  # Adjust verbosity as needed
    )
    
    # Load the best model
    best_model = load_model('best_model.keras')
    
    # Predict on the test set
    y_pred = best_model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_generator.classes
    
    # Generate classification report
    report = classification_report(y_true, y_pred_classes, 
                                 target_names=class_names,
                                 output_dict=True)
    
    # Collect metrics for each class
    for cls in class_names:
        metrics['classes'][cls]['precision'].append(report[cls]['precision'])
        metrics['classes'][cls]['recall'].append(report[cls]['recall'])
        metrics['classes'][cls]['f1'].append(report[cls]['f1-score'])
    
    # Collect macro and weighted averages
    metrics['macro_avg']['precision'].append(report['macro avg']['precision'])
    metrics['macro_avg']['recall'].append(report['macro avg']['recall'])
    metrics['macro_avg']['f1'].append(report['macro avg']['f1-score'])
    
    metrics['weighted_avg']['precision'].append(report['weighted avg']['precision'])
    metrics['weighted_avg']['recall'].append(report['weighted avg']['recall'])
    metrics['weighted_avg']['f1'].append(report['weighted avg']['f1-score'])
    
    # Collect accuracy
    metrics['accuracy'].append(report['accuracy'])
# Out:
# =========== Training Run 1/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.8143 - loss: 0.8051 - val_accuracy: 0.8959 - val_loss: 0.3345
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.8501 - loss: 0.4581 - val_accuracy: 0.9104 - val_loss: 0.3177
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 239ms/step - accuracy: 0.8546 - loss: 0.4079 - val_accuracy: 0.9056 - val_loss: 0.2490
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8636 - loss: 0.3809 - val_accuracy: 0.9128 - val_loss: 0.2690
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8598 - loss: 0.3931 - val_accuracy: 0.9177 - val_loss: 0.2273
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8843 - loss: 0.3568 - val_accuracy: 0.9298 - val_loss: 0.2116
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8619 - loss: 0.3535 - val_accuracy: 0.9298 - val_loss: 0.2054
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8932 - loss: 0.3156 - val_accuracy: 0.9395 - val_loss: 0.1894
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9037 - loss: 0.2777 - val_accuracy: 0.8983 - val_loss: 0.2346
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8722 - loss: 0.4379 - val_accuracy: 0.9274 - val_loss: 0.2065
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8752 - loss: 0.3503 - val_accuracy: 0.9201 - val_loss: 0.2237
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8988 - loss: 0.3219 - val_accuracy: 0.9443 - val_loss: 0.2019
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8975 - loss: 0.2522 - val_accuracy: 0.9322 - val_loss: 0.1974
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
#
# =========== Training Run 2/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.7973 - loss: 0.8437 - val_accuracy: 0.9007 - val_loss: 0.2542
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8580 - loss: 0.4089 - val_accuracy: 0.9128 - val_loss: 0.2140
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8679 - loss: 0.3899 - val_accuracy: 0.9153 - val_loss: 0.2332
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8919 - loss: 0.2989 - val_accuracy: 0.9249 - val_loss: 0.2165
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8610 - loss: 0.3420 - val_accuracy: 0.8935 - val_loss: 0.2721
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8751 - loss: 0.3314 - val_accuracy: 0.9201 - val_loss: 0.2079
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8821 - loss: 0.3261 - val_accuracy: 0.9322 - val_loss: 0.2075
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8802 - loss: 0.3423 - val_accuracy: 0.9249 - val_loss: 0.2117
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8941 - loss: 0.3069 - val_accuracy: 0.8983 - val_loss: 0.2640
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8908 - loss: 0.3096 - val_accuracy: 0.9298 - val_loss: 0.2034
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8811 - loss: 0.3205 - val_accuracy: 0.9249 - val_loss: 0.2149
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9104 - loss: 0.2613 - val_accuracy: 0.9298 - val_loss: 0.1884
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9147 - loss: 0.2483 - val_accuracy: 0.9249 - val_loss: 0.2121
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8952 - loss: 0.2672 - val_accuracy: 0.9346 - val_loss: 0.1941
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8998 - loss: 0.2690 - val_accuracy: 0.9225 - val_loss: 0.1887
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.9067 - loss: 0.2361 - val_accuracy: 0.9370 - val_loss: 0.1776
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.9041 - loss: 0.2388 - val_accuracy: 0.9467 - val_loss: 0.1857
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9017 - loss: 0.2336 - val_accuracy: 0.9346 - val_loss: 0.2244
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9120 - loss: 0.2295 - val_accuracy: 0.9274 - val_loss: 0.1856
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9018 - loss: 0.2729 - val_accuracy: 0.9298 - val_loss: 0.1600
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9129 - loss: 0.2262 - val_accuracy: 0.9613 - val_loss: 0.1455
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9217 - loss: 0.2119 - val_accuracy: 0.9346 - val_loss: 0.1704
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9110 - loss: 0.2234 - val_accuracy: 0.9467 - val_loss: 0.1775
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9073 - loss: 0.2355 - val_accuracy: 0.9274 - val_loss: 0.2147
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9102 - loss: 0.2581 - val_accuracy: 0.9516 - val_loss: 0.1587
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9207 - loss: 0.2021 - val_accuracy: 0.9443 - val_loss: 0.1585
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#
# =========== Training Run 3/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.8050 - loss: 0.8351 - val_accuracy: 0.9201 - val_loss: 0.2472
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8597 - loss: 0.4492 - val_accuracy: 0.9056 - val_loss: 0.3152
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 262ms/step - accuracy: 0.8753 - loss: 0.3763 - val_accuracy: 0.9007 - val_loss: 0.2448
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8731 - loss: 0.3482 - val_accuracy: 0.9298 - val_loss: 0.1999
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8837 - loss: 0.3275 - val_accuracy: 0.9346 - val_loss: 0.1961
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8740 - loss: 0.3434 - val_accuracy: 0.9249 - val_loss: 0.2055
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8820 - loss: 0.3266 - val_accuracy: 0.9153 - val_loss: 0.2031
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8858 - loss: 0.3049 - val_accuracy: 0.9225 - val_loss: 0.2187
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9063 - loss: 0.2825 - val_accuracy: 0.9370 - val_loss: 0.2111
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8911 - loss: 0.2873 - val_accuracy: 0.9370 - val_loss: 0.1958
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8967 - loss: 0.2988 - val_accuracy: 0.9346 - val_loss: 0.2099
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8960 - loss: 0.3090 - val_accuracy: 0.9370 - val_loss: 0.1933
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8989 - loss: 0.3045 - val_accuracy: 0.9370 - val_loss: 0.1846
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8973 - loss: 0.2691 - val_accuracy: 0.9395 - val_loss: 0.1828
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9046 - loss: 0.2745 - val_accuracy: 0.9370 - val_loss: 0.1810
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9145 - loss: 0.2405 - val_accuracy: 0.9370 - val_loss: 0.1761
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9109 - loss: 0.2263 - val_accuracy: 0.9249 - val_loss: 0.2170
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9065 - loss: 0.2460 - val_accuracy: 0.9419 - val_loss: 0.1643
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9199 - loss: 0.2235 - val_accuracy: 0.9395 - val_loss: 0.1695
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9152 - loss: 0.2095 - val_accuracy: 0.9322 - val_loss: 0.1923
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9228 - loss: 0.2027 - val_accuracy: 0.9419 - val_loss: 0.1630
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9200 - loss: 0.2368 - val_accuracy: 0.9467 - val_loss: 0.1652
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9153 - loss: 0.2464 - val_accuracy: 0.9346 - val_loss: 0.1619
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9324 - loss: 0.1827 - val_accuracy: 0.9443 - val_loss: 0.1508
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9135 - loss: 0.2320 - val_accuracy: 0.9153 - val_loss: 0.2041
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9151 - loss: 0.2071 - val_accuracy: 0.9419 - val_loss: 0.1720
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9197 - loss: 0.2087 - val_accuracy: 0.9588 - val_loss: 0.1376
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9238 - loss: 0.1956 - val_accuracy: 0.9492 - val_loss: 0.1484
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9341 - loss: 0.1901 - val_accuracy: 0.9516 - val_loss: 0.1577
# Epoch 30/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9280 - loss: 0.1962 - val_accuracy: 0.9395 - val_loss: 0.1617
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
#
# =========== Training Run 4/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.7805 - loss: 0.9229 - val_accuracy: 0.9031 - val_loss: 0.2950
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8593 - loss: 0.4376 - val_accuracy: 0.9298 - val_loss: 0.1936
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8611 - loss: 0.3966 - val_accuracy: 0.9274 - val_loss: 0.2094
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8654 - loss: 0.3732 - val_accuracy: 0.9249 - val_loss: 0.2282
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8698 - loss: 0.3684 - val_accuracy: 0.9225 - val_loss: 0.2810
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8712 - loss: 0.3585 - val_accuracy: 0.9056 - val_loss: 0.2046
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8755 - loss: 0.3273 - val_accuracy: 0.9346 - val_loss: 0.1996
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#
# =========== Training Run 5/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 248ms/step - accuracy: 0.7805 - loss: 0.8858 - val_accuracy: 0.8959 - val_loss: 0.2670
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8532 - loss: 0.4455 - val_accuracy: 0.9153 - val_loss: 0.3185
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8675 - loss: 0.4089 - val_accuracy: 0.9201 - val_loss: 0.2464
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8710 - loss: 0.3426 - val_accuracy: 0.9322 - val_loss: 0.2109
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8663 - loss: 0.3377 - val_accuracy: 0.9104 - val_loss: 0.2350
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8708 - loss: 0.3701 - val_accuracy: 0.9080 - val_loss: 0.2329
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9001 - loss: 0.2735 - val_accuracy: 0.9201 - val_loss: 0.2024
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8839 - loss: 0.2878 - val_accuracy: 0.9274 - val_loss: 0.1972
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8905 - loss: 0.3044 - val_accuracy: 0.9153 - val_loss: 0.2323
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8934 - loss: 0.3295 - val_accuracy: 0.9346 - val_loss: 0.2099
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8818 - loss: 0.3350 - val_accuracy: 0.9370 - val_loss: 0.2007
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8945 - loss: 0.2980 - val_accuracy: 0.9395 - val_loss: 0.1977
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 259ms/step - accuracy: 0.9025 - loss: 0.2735 - val_accuracy: 0.9395 - val_loss: 0.1833
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8902 - loss: 0.2902 - val_accuracy: 0.9346 - val_loss: 0.1950
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8994 - loss: 0.2518 - val_accuracy: 0.9540 - val_loss: 0.1660
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9097 - loss: 0.2379 - val_accuracy: 0.9370 - val_loss: 0.1824
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9123 - loss: 0.2562 - val_accuracy: 0.9467 - val_loss: 0.1838
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8998 - loss: 0.2632 - val_accuracy: 0.9395 - val_loss: 0.2025
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9052 - loss: 0.2507 - val_accuracy: 0.9395 - val_loss: 0.1808
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8975 - loss: 0.2657 - val_accuracy: 0.9322 - val_loss: 0.1945
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#
# =========== Training Run 6/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.8118 - loss: 0.7633 - val_accuracy: 0.8959 - val_loss: 0.2903
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8515 - loss: 0.4648 - val_accuracy: 0.9225 - val_loss: 0.2570
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8705 - loss: 0.4041 - val_accuracy: 0.9080 - val_loss: 0.2826
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8782 - loss: 0.3741 - val_accuracy: 0.8983 - val_loss: 0.2765
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 258ms/step - accuracy: 0.8659 - loss: 0.3839 - val_accuracy: 0.9177 - val_loss: 0.2293
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8718 - loss: 0.4050 - val_accuracy: 0.9201 - val_loss: 0.1941
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8789 - loss: 0.3286 - val_accuracy: 0.9249 - val_loss: 0.2107
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8961 - loss: 0.3258 - val_accuracy: 0.9177 - val_loss: 0.2092
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8735 - loss: 0.3791 - val_accuracy: 0.9346 - val_loss: 0.1932
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8782 - loss: 0.3261 - val_accuracy: 0.9104 - val_loss: 0.2187
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8850 - loss: 0.2963 - val_accuracy: 0.9322 - val_loss: 0.1861
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8761 - loss: 0.4377 - val_accuracy: 0.9249 - val_loss: 0.2330
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8689 - loss: 0.3890 - val_accuracy: 0.9298 - val_loss: 0.1992
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8997 - loss: 0.3053 - val_accuracy: 0.9153 - val_loss: 0.2333
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8855 - loss: 0.3088 - val_accuracy: 0.9153 - val_loss: 0.2472
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8752 - loss: 0.3530 - val_accuracy: 0.9249 - val_loss: 0.2054
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# =========== Training Run 7/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.8216 - loss: 0.7694 - val_accuracy: 0.8959 - val_loss: 0.3050
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8518 - loss: 0.5278 - val_accuracy: 0.9128 - val_loss: 0.2820
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8781 - loss: 0.3853 - val_accuracy: 0.9177 - val_loss: 0.2332
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8897 - loss: 0.3471 - val_accuracy: 0.9249 - val_loss: 0.2080
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8756 - loss: 0.3656 - val_accuracy: 0.9274 - val_loss: 0.2641
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8797 - loss: 0.3471 - val_accuracy: 0.9322 - val_loss: 0.2111
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8756 - loss: 0.3584 - val_accuracy: 0.9177 - val_loss: 0.2056
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8723 - loss: 0.4028 - val_accuracy: 0.9201 - val_loss: 0.2248
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8934 - loss: 0.2899 - val_accuracy: 0.9322 - val_loss: 0.2000
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8874 - loss: 0.3050 - val_accuracy: 0.9201 - val_loss: 0.2249
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8921 - loss: 0.2951 - val_accuracy: 0.9128 - val_loss: 0.2418
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8867 - loss: 0.3098 - val_accuracy: 0.9298 - val_loss: 0.1942
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8885 - loss: 0.3022 - val_accuracy: 0.9225 - val_loss: 0.2166
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8952 - loss: 0.3107 - val_accuracy: 0.9443 - val_loss: 0.1661
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.9117 - loss: 0.2837 - val_accuracy: 0.9395 - val_loss: 0.1965
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9058 - loss: 0.2708 - val_accuracy: 0.9346 - val_loss: 0.1930
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9173 - loss: 0.2246 - val_accuracy: 0.9419 - val_loss: 0.2198
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9061 - loss: 0.2671 - val_accuracy: 0.9492 - val_loss: 0.1773
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9233 - loss: 0.2108 - val_accuracy: 0.9516 - val_loss: 0.1808
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# =========== Training Run 8/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.8270 - loss: 0.7887 - val_accuracy: 0.9080 - val_loss: 0.2377
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8555 - loss: 0.4777 - val_accuracy: 0.9153 - val_loss: 0.2424
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8609 - loss: 0.3921 - val_accuracy: 0.9298 - val_loss: 0.2249
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 0.8856 - loss: 0.3366 - val_accuracy: 0.9031 - val_loss: 0.2390
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8571 - loss: 0.3892 - val_accuracy: 0.9177 - val_loss: 0.2085
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8745 - loss: 0.3354 - val_accuracy: 0.9104 - val_loss: 0.2146
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8690 - loss: 0.3611 - val_accuracy: 0.9322 - val_loss: 0.2110
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8921 - loss: 0.3282 - val_accuracy: 0.9177 - val_loss: 0.2253
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8823 - loss: 0.3417 - val_accuracy: 0.9443 - val_loss: 0.1915
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8903 - loss: 0.3254 - val_accuracy: 0.9322 - val_loss: 0.2531
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8767 - loss: 0.3305 - val_accuracy: 0.9128 - val_loss: 0.2644
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8956 - loss: 0.2801 - val_accuracy: 0.9322 - val_loss: 0.1979
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8850 - loss: 0.3111 - val_accuracy: 0.9370 - val_loss: 0.2045
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8943 - loss: 0.3008 - val_accuracy: 0.9419 - val_loss: 0.1751
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 258ms/step - accuracy: 0.8927 - loss: 0.2924 - val_accuracy: 0.9419 - val_loss: 0.1788
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9025 - loss: 0.2869 - val_accuracy: 0.9274 - val_loss: 0.2013
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9029 - loss: 0.2766 - val_accuracy: 0.9153 - val_loss: 0.2109
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8934 - loss: 0.2689 - val_accuracy: 0.9346 - val_loss: 0.1761
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9233 - loss: 0.2111 - val_accuracy: 0.9201 - val_loss: 0.2056
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
#
# =========== Training Run 9/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 251ms/step - accuracy: 0.8132 - loss: 0.8025 - val_accuracy: 0.8983 - val_loss: 0.2852
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8560 - loss: 0.4705 - val_accuracy: 0.9031 - val_loss: 0.2856
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8716 - loss: 0.3957 - val_accuracy: 0.9056 - val_loss: 0.2416
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8801 - loss: 0.3357 - val_accuracy: 0.9249 - val_loss: 0.1984
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8793 - loss: 0.3441 - val_accuracy: 0.9346 - val_loss: 0.1943
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8857 - loss: 0.3140 - val_accuracy: 0.9128 - val_loss: 0.2199
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8710 - loss: 0.3312 - val_accuracy: 0.9104 - val_loss: 0.2310
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8921 - loss: 0.2934 - val_accuracy: 0.9153 - val_loss: 0.2188
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8805 - loss: 0.3301 - val_accuracy: 0.9177 - val_loss: 0.2148
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8770 - loss: 0.3445 - val_accuracy: 0.9104 - val_loss: 0.5097
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
#
# =========== Training Run 10/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 248ms/step - accuracy: 0.8111 - loss: 0.7549 - val_accuracy: 0.9007 - val_loss: 0.3082
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.8511 - loss: 0.4842 - val_accuracy: 0.9177 - val_loss: 0.2222
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8868 - loss: 0.3306 - val_accuracy: 0.9298 - val_loss: 0.1941
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8777 - loss: 0.3597 - val_accuracy: 0.9249 - val_loss: 0.2054
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8905 - loss: 0.3221 - val_accuracy: 0.9201 - val_loss: 0.1991
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8864 - loss: 0.3158 - val_accuracy: 0.9274 - val_loss: 0.2160
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8838 - loss: 0.3386 - val_accuracy: 0.9201 - val_loss: 0.2441
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8828 - loss: 0.3426 - val_accuracy: 0.9249 - val_loss: 0.2041
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#
# =========== Training Run 11/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 245ms/step - accuracy: 0.7899 - loss: 0.9244 - val_accuracy: 0.8959 - val_loss: 0.3525
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8609 - loss: 0.4470 - val_accuracy: 0.9056 - val_loss: 0.2431
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8551 - loss: 0.4261 - val_accuracy: 0.9007 - val_loss: 0.3271
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8625 - loss: 0.4488 - val_accuracy: 0.9201 - val_loss: 0.2250
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8825 - loss: 0.3369 - val_accuracy: 0.9225 - val_loss: 0.2525
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8827 - loss: 0.3426 - val_accuracy: 0.9128 - val_loss: 0.2266
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8756 - loss: 0.3410 - val_accuracy: 0.9274 - val_loss: 0.2156
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8781 - loss: 0.3376 - val_accuracy: 0.9225 - val_loss: 0.2229
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8746 - loss: 0.3287 - val_accuracy: 0.9201 - val_loss: 0.2015
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 0.8737 - loss: 0.3399 - val_accuracy: 0.9322 - val_loss: 0.2253
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9051 - loss: 0.2567 - val_accuracy: 0.8935 - val_loss: 0.2697
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8886 - loss: 0.3068 - val_accuracy: 0.9201 - val_loss: 0.2467
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8745 - loss: 0.3605 - val_accuracy: 0.9104 - val_loss: 0.2110
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8835 - loss: 0.2879 - val_accuracy: 0.9153 - val_loss: 0.3056
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# =========== Training Run 12/30 ===========
# Epoch 1/30
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.8197 - loss: 0.8259 - val_accuracy: 0.9056 - val_loss: 0.3224
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8633 - loss: 0.5112 - val_accuracy: 0.9031 - val_loss: 0.2468
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8540 - loss: 0.4271 - val_accuracy: 0.9249 - val_loss: 0.2130
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8878 - loss: 0.3488 - val_accuracy: 0.9177 - val_loss: 0.3347
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8767 - loss: 0.3949 - val_accuracy: 0.9104 - val_loss: 0.2254
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8874 - loss: 0.3343 - val_accuracy: 0.9249 - val_loss: 0.2029
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8840 - loss: 0.3128 - val_accuracy: 0.9080 - val_loss: 0.3243
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8755 - loss: 0.3947 - val_accuracy: 0.9370 - val_loss: 0.1937
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8932 - loss: 0.2814 - val_accuracy: 0.9249 - val_loss: 0.2195
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8896 - loss: 0.3028 - val_accuracy: 0.8814 - val_loss: 0.3172
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8936 - loss: 0.3002 - val_accuracy: 0.9201 - val_loss: 0.2178
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8946 - loss: 0.2919 - val_accuracy: 0.9322 - val_loss: 0.1847
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9078 - loss: 0.2595 - val_accuracy: 0.9274 - val_loss: 0.1903
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9177 - loss: 0.2385 - val_accuracy: 0.9370 - val_loss: 0.1836
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9098 - loss: 0.2541 - val_accuracy: 0.9274 - val_loss: 0.2116
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8844 - loss: 0.2912 - val_accuracy: 0.9467 - val_loss: 0.1625
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9184 - loss: 0.2391 - val_accuracy: 0.9298 - val_loss: 0.1740
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9089 - loss: 0.2620 - val_accuracy: 0.9225 - val_loss: 0.2105
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9070 - loss: 0.2527 - val_accuracy: 0.9322 - val_loss: 0.1850
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.9148 - loss: 0.2181 - val_accuracy: 0.9370 - val_loss: 0.1609
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 272ms/step - accuracy: 0.9092 - loss: 0.2379 - val_accuracy: 0.9467 - val_loss: 0.1713
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.9066 - loss: 0.2614 - val_accuracy: 0.9443 - val_loss: 0.1709
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9102 - loss: 0.2751 - val_accuracy: 0.9395 - val_loss: 0.1933
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9094 - loss: 0.2359 - val_accuracy: 0.9540 - val_loss: 0.1554
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9346 - loss: 0.1920 - val_accuracy: 0.9346 - val_loss: 0.1750
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9190 - loss: 0.2045 - val_accuracy: 0.9322 - val_loss: 0.1597
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9229 - loss: 0.2061 - val_accuracy: 0.9370 - val_loss: 0.1440
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9140 - loss: 0.2371 - val_accuracy: 0.9443 - val_loss: 0.1656
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9335 - loss: 0.2038 - val_accuracy: 0.9467 - val_loss: 0.1618
# Epoch 30/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9152 - loss: 0.2258 - val_accuracy: 0.9492 - val_loss: 0.1539
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# =========== Training Run 13/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.7928 - loss: 0.7737 - val_accuracy: 0.8959 - val_loss: 0.3025
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8481 - loss: 0.4788 - val_accuracy: 0.9056 - val_loss: 0.2357
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8692 - loss: 0.3980 - val_accuracy: 0.9249 - val_loss: 0.2832
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8868 - loss: 0.3444 - val_accuracy: 0.9201 - val_loss: 0.2006
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8769 - loss: 0.3454 - val_accuracy: 0.9370 - val_loss: 0.1859
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 0.8749 - loss: 0.3770 - val_accuracy: 0.9153 - val_loss: 0.2405
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8915 - loss: 0.3015 - val_accuracy: 0.9395 - val_loss: 0.2018
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8891 - loss: 0.3081 - val_accuracy: 0.9395 - val_loss: 0.1816
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8949 - loss: 0.3038 - val_accuracy: 0.9249 - val_loss: 0.2166
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8985 - loss: 0.3107 - val_accuracy: 0.9322 - val_loss: 0.1999
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.9000 - loss: 0.2900 - val_accuracy: 0.9395 - val_loss: 0.1789
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9140 - loss: 0.2438 - val_accuracy: 0.9322 - val_loss: 0.2153
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9164 - loss: 0.2477 - val_accuracy: 0.9298 - val_loss: 0.2080
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8974 - loss: 0.2887 - val_accuracy: 0.9298 - val_loss: 0.2351
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8978 - loss: 0.3032 - val_accuracy: 0.9153 - val_loss: 0.2672
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9099 - loss: 0.3276 - val_accuracy: 0.9225 - val_loss: 0.2469
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# =========== Training Run 14/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.7851 - loss: 0.8143 - val_accuracy: 0.8959 - val_loss: 0.6814
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8530 - loss: 0.5677 - val_accuracy: 0.8983 - val_loss: 0.3703
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8552 - loss: 0.4442 - val_accuracy: 0.9007 - val_loss: 0.2897
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8701 - loss: 0.3840 - val_accuracy: 0.9056 - val_loss: 0.2872
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8743 - loss: 0.3761 - val_accuracy: 0.9056 - val_loss: 0.2468
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8678 - loss: 0.4019 - val_accuracy: 0.9056 - val_loss: 0.2549
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8829 - loss: 0.3302 - val_accuracy: 0.9225 - val_loss: 0.2438
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8861 - loss: 0.3420 - val_accuracy: 0.9274 - val_loss: 0.2129
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8851 - loss: 0.3261 - val_accuracy: 0.9225 - val_loss: 0.2188
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8858 - loss: 0.3032 - val_accuracy: 0.9346 - val_loss: 0.1914
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8944 - loss: 0.2823 - val_accuracy: 0.9080 - val_loss: 0.2883
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8852 - loss: 0.3714 - val_accuracy: 0.9177 - val_loss: 0.2234
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9010 - loss: 0.2725 - val_accuracy: 0.9298 - val_loss: 0.1960
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9064 - loss: 0.2552 - val_accuracy: 0.9322 - val_loss: 0.1897
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9085 - loss: 0.2559 - val_accuracy: 0.9249 - val_loss: 0.1963
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8978 - loss: 0.2745 - val_accuracy: 0.9322 - val_loss: 0.1844
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9142 - loss: 0.2521 - val_accuracy: 0.9322 - val_loss: 0.2106
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9059 - loss: 0.2541 - val_accuracy: 0.8959 - val_loss: 0.2320
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9073 - loss: 0.2462 - val_accuracy: 0.9395 - val_loss: 0.1848
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9176 - loss: 0.2149 - val_accuracy: 0.9274 - val_loss: 0.2458
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9150 - loss: 0.2425 - val_accuracy: 0.9346 - val_loss: 0.1910
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#
# =========== Training Run 15/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 245ms/step - accuracy: 0.8218 - loss: 0.7968 - val_accuracy: 0.8959 - val_loss: 0.3656
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8567 - loss: 0.4745 - val_accuracy: 0.9056 - val_loss: 0.2862
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8639 - loss: 0.4139 - val_accuracy: 0.9153 - val_loss: 0.2395
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8711 - loss: 0.3472 - val_accuracy: 0.8862 - val_loss: 0.5383
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8737 - loss: 0.3781 - val_accuracy: 0.9007 - val_loss: 0.2718
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8673 - loss: 0.3803 - val_accuracy: 0.9274 - val_loss: 0.2023
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8735 - loss: 0.3494 - val_accuracy: 0.9080 - val_loss: 0.2577
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8748 - loss: 0.3629 - val_accuracy: 0.9249 - val_loss: 0.2091
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8788 - loss: 0.3365 - val_accuracy: 0.9128 - val_loss: 0.2169
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8890 - loss: 0.3178 - val_accuracy: 0.9177 - val_loss: 0.2715
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8806 - loss: 0.3249 - val_accuracy: 0.9274 - val_loss: 0.1975
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8787 - loss: 0.2960 - val_accuracy: 0.9080 - val_loss: 0.2242
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.8877 - loss: 0.3409 - val_accuracy: 0.9370 - val_loss: 0.1991
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8821 - loss: 0.3045 - val_accuracy: 0.9225 - val_loss: 0.1993
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8921 - loss: 0.2700 - val_accuracy: 0.9249 - val_loss: 0.1993
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9033 - loss: 0.2723 - val_accuracy: 0.9419 - val_loss: 0.1767
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9015 - loss: 0.2738 - val_accuracy: 0.8838 - val_loss: 0.2807
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8906 - loss: 0.3030 - val_accuracy: 0.9419 - val_loss: 0.1960
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 258ms/step - accuracy: 0.8737 - loss: 0.3260 - val_accuracy: 0.9419 - val_loss: 0.1689
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.9037 - loss: 0.2882 - val_accuracy: 0.9467 - val_loss: 0.1777
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9051 - loss: 0.2470 - val_accuracy: 0.9249 - val_loss: 0.2033
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9211 - loss: 0.2699 - val_accuracy: 0.9249 - val_loss: 0.2365
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 262ms/step - accuracy: 0.9013 - loss: 0.2946 - val_accuracy: 0.9225 - val_loss: 0.2085
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 262ms/step - accuracy: 0.9133 - loss: 0.2437 - val_accuracy: 0.9516 - val_loss: 0.1528
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9019 - loss: 0.2676 - val_accuracy: 0.9419 - val_loss: 0.1765
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9238 - loss: 0.2053 - val_accuracy: 0.9419 - val_loss: 0.1747
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.9261 - loss: 0.2055 - val_accuracy: 0.9516 - val_loss: 0.1574
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9235 - loss: 0.2203 - val_accuracy: 0.9346 - val_loss: 0.1826
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.9041 - loss: 0.2172 - val_accuracy: 0.9588 - val_loss: 0.1549
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# =========== Training Run 16/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.7946 - loss: 1.0141 - val_accuracy: 0.9128 - val_loss: 0.2937
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8556 - loss: 0.4658 - val_accuracy: 0.8959 - val_loss: 0.2514
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8527 - loss: 0.3877 - val_accuracy: 0.9080 - val_loss: 0.2169
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8793 - loss: 0.3162 - val_accuracy: 0.9153 - val_loss: 0.2158
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8655 - loss: 0.3524 - val_accuracy: 0.8668 - val_loss: 0.3390
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8798 - loss: 0.3257 - val_accuracy: 0.9370 - val_loss: 0.2080
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8909 - loss: 0.3270 - val_accuracy: 0.9153 - val_loss: 0.2054
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8776 - loss: 0.2927 - val_accuracy: 0.9322 - val_loss: 0.2022
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8875 - loss: 0.2840 - val_accuracy: 0.9249 - val_loss: 0.2255
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8915 - loss: 0.3235 - val_accuracy: 0.9249 - val_loss: 0.2100
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8945 - loss: 0.2810 - val_accuracy: 0.9128 - val_loss: 0.2542
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8744 - loss: 0.3521 - val_accuracy: 0.9249 - val_loss: 0.2432
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8847 - loss: 0.3221 - val_accuracy: 0.9346 - val_loss: 0.1961
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8923 - loss: 0.3012 - val_accuracy: 0.9153 - val_loss: 0.2232
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.9046 - loss: 0.2971 - val_accuracy: 0.9201 - val_loss: 0.2163
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.9004 - loss: 0.2506 - val_accuracy: 0.9298 - val_loss: 0.1958
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9025 - loss: 0.2628 - val_accuracy: 0.9395 - val_loss: 0.1754
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8973 - loss: 0.2453 - val_accuracy: 0.9346 - val_loss: 0.2051
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9024 - loss: 0.3021 - val_accuracy: 0.9201 - val_loss: 0.2311
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 244ms/step - accuracy: 0.8930 - loss: 0.3060 - val_accuracy: 0.9249 - val_loss: 0.2047
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.9027 - loss: 0.2803 - val_accuracy: 0.9298 - val_loss: 0.1961
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.9019 - loss: 0.2913 - val_accuracy: 0.9104 - val_loss: 0.2331
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# =========== Training Run 17/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 248ms/step - accuracy: 0.7835 - loss: 0.8747 - val_accuracy: 0.9031 - val_loss: 0.3445
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8583 - loss: 0.4429 - val_accuracy: 0.9225 - val_loss: 0.3230
# ...
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8879 - loss: 0.3362 - val_accuracy: 0.9225 - val_loss: 0.2138
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8935 - loss: 0.3491 - val_accuracy: 0.9274 - val_loss: 0.2147
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8834 - loss: 0.3356 - val_accuracy: 0.9177 - val_loss: 0.2614
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8697 - loss: 0.3882 - val_accuracy: 0.9225 - val_loss: 0.2165
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 257ms/step - accuracy: 0.8914 - loss: 0.2889 - val_accuracy: 0.9225 - val_loss: 0.2060
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
#
# =========== Training Run 26/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.7846 - loss: 0.7952 - val_accuracy: 0.9007 - val_loss: 0.2890
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8537 - loss: 0.4806 - val_accuracy: 0.8741 - val_loss: 0.3312
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 17s 284ms/step - accuracy: 0.8821 - loss: 0.3950 - val_accuracy: 0.9249 - val_loss: 0.2551
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 260ms/step - accuracy: 0.8836 - loss: 0.3380 - val_accuracy: 0.9201 - val_loss: 0.2667
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.8777 - loss: 0.3373 - val_accuracy: 0.9056 - val_loss: 0.2434
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8699 - loss: 0.3433 - val_accuracy: 0.9177 - val_loss: 0.2164
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8850 - loss: 0.3232 - val_accuracy: 0.9298 - val_loss: 0.2222
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8782 - loss: 0.3438 - val_accuracy: 0.9128 - val_loss: 0.2427
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8846 - loss: 0.3294 - val_accuracy: 0.9128 - val_loss: 0.2194
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.8827 - loss: 0.3066 - val_accuracy: 0.9249 - val_loss: 0.2071
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8989 - loss: 0.2931 - val_accuracy: 0.9395 - val_loss: 0.1981
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8733 - loss: 0.3196 - val_accuracy: 0.9370 - val_loss: 0.1874
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8992 - loss: 0.3021 - val_accuracy: 0.9370 - val_loss: 0.1992
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8973 - loss: 0.2729 - val_accuracy: 0.9395 - val_loss: 0.1950
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9055 - loss: 0.2628 - val_accuracy: 0.9395 - val_loss: 0.1917
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.9044 - loss: 0.2752 - val_accuracy: 0.9467 - val_loss: 0.1679
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.9001 - loss: 0.2467 - val_accuracy: 0.9467 - val_loss: 0.1835
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.8945 - loss: 0.2510 - val_accuracy: 0.9346 - val_loss: 0.1881
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9094 - loss: 0.2246 - val_accuracy: 0.9346 - val_loss: 0.1819
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9056 - loss: 0.2468 - val_accuracy: 0.9467 - val_loss: 0.1611
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.9122 - loss: 0.2312 - val_accuracy: 0.9419 - val_loss: 0.1829
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9011 - loss: 0.2472 - val_accuracy: 0.9322 - val_loss: 0.1741
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8983 - loss: 0.2298 - val_accuracy: 0.9419 - val_loss: 0.1738
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.9147 - loss: 0.2311 - val_accuracy: 0.9443 - val_loss: 0.1566
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.9210 - loss: 0.2241 - val_accuracy: 0.9274 - val_loss: 0.1995
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9073 - loss: 0.2406 - val_accuracy: 0.9467 - val_loss: 0.1572
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9206 - loss: 0.2299 - val_accuracy: 0.9467 - val_loss: 0.1625
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9279 - loss: 0.1999 - val_accuracy: 0.9467 - val_loss: 0.1531
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9211 - loss: 0.2196 - val_accuracy: 0.9443 - val_loss: 0.1543
# Epoch 30/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9067 - loss: 0.2319 - val_accuracy: 0.9516 - val_loss: 0.1681
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
#
# =========== Training Run 27/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - accuracy: 0.8111 - loss: 0.8609 - val_accuracy: 0.8983 - val_loss: 0.3016
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8630 - loss: 0.4664 - val_accuracy: 0.8983 - val_loss: 0.2932
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8696 - loss: 0.4081 - val_accuracy: 0.9056 - val_loss: 0.2513
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8742 - loss: 0.3487 - val_accuracy: 0.9128 - val_loss: 0.2607
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8825 - loss: 0.3597 - val_accuracy: 0.9225 - val_loss: 0.2043
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8763 - loss: 0.3295 - val_accuracy: 0.9249 - val_loss: 0.2114
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8810 - loss: 0.3245 - val_accuracy: 0.9298 - val_loss: 0.2094
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8758 - loss: 0.3649 - val_accuracy: 0.9346 - val_loss: 0.2133
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8952 - loss: 0.3080 - val_accuracy: 0.9225 - val_loss: 0.2087
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8943 - loss: 0.2669 - val_accuracy: 0.9201 - val_loss: 0.1938
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8969 - loss: 0.2844 - val_accuracy: 0.9443 - val_loss: 0.1835
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.9012 - loss: 0.2704 - val_accuracy: 0.9322 - val_loss: 0.1821
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9006 - loss: 0.3039 - val_accuracy: 0.9298 - val_loss: 0.1932
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8977 - loss: 0.2841 - val_accuracy: 0.9322 - val_loss: 0.2049
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.8939 - loss: 0.2725 - val_accuracy: 0.9467 - val_loss: 0.1744
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.8992 - loss: 0.2712 - val_accuracy: 0.9298 - val_loss: 0.2029
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9174 - loss: 0.2727 - val_accuracy: 0.8959 - val_loss: 0.2771
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9032 - loss: 0.2657 - val_accuracy: 0.9467 - val_loss: 0.1788
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9007 - loss: 0.3057 - val_accuracy: 0.9395 - val_loss: 0.1669
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9085 - loss: 0.2643 - val_accuracy: 0.9395 - val_loss: 0.1496
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8926 - loss: 0.3127 - val_accuracy: 0.9370 - val_loss: 0.1948
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9197 - loss: 0.2219 - val_accuracy: 0.9395 - val_loss: 0.1854
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9089 - loss: 0.2438 - val_accuracy: 0.9467 - val_loss: 0.1744
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9032 - loss: 0.2575 - val_accuracy: 0.9274 - val_loss: 0.2104
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.8947 - loss: 0.3008 - val_accuracy: 0.9395 - val_loss: 0.1778
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
#
# =========== Training Run 28/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.8034 - loss: 0.7963 - val_accuracy: 0.9007 - val_loss: 0.3049
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8602 - loss: 0.4385 - val_accuracy: 0.8983 - val_loss: 0.3580
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8770 - loss: 0.3775 - val_accuracy: 0.9201 - val_loss: 0.2430
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8661 - loss: 0.3776 - val_accuracy: 0.9249 - val_loss: 0.2070
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8606 - loss: 0.3819 - val_accuracy: 0.9201 - val_loss: 0.2157
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 257ms/step - accuracy: 0.8736 - loss: 0.3466 - val_accuracy: 0.9201 - val_loss: 0.2080
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8960 - loss: 0.2717 - val_accuracy: 0.9249 - val_loss: 0.2209
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8827 - loss: 0.3135 - val_accuracy: 0.9104 - val_loss: 0.2843
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8633 - loss: 0.4182 - val_accuracy: 0.9177 - val_loss: 0.2180
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
#
# =========== Training Run 29/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 251ms/step - accuracy: 0.8043 - loss: 0.7881 - val_accuracy: 0.8959 - val_loss: 0.3598
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8430 - loss: 0.4762 - val_accuracy: 0.8959 - val_loss: 0.6140
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.8459 - loss: 0.5671 - val_accuracy: 0.9031 - val_loss: 0.2926
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.8719 - loss: 0.3778 - val_accuracy: 0.9153 - val_loss: 0.2434
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8775 - loss: 0.3980 - val_accuracy: 0.9056 - val_loss: 0.2519
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8780 - loss: 0.3542 - val_accuracy: 0.9153 - val_loss: 0.2175
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8770 - loss: 0.4079 - val_accuracy: 0.9080 - val_loss: 0.2887
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 257ms/step - accuracy: 0.8868 - loss: 0.3600 - val_accuracy: 0.9177 - val_loss: 0.2317
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.8770 - loss: 0.3961 - val_accuracy: 0.9201 - val_loss: 0.2174
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8866 - loss: 0.3520 - val_accuracy: 0.9298 - val_loss: 0.2608
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9019 - loss: 0.3200 - val_accuracy: 0.8983 - val_loss: 0.2993
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8766 - loss: 0.3587 - val_accuracy: 0.9249 - val_loss: 0.1997
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8908 - loss: 0.3045 - val_accuracy: 0.9443 - val_loss: 0.1941
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9044 - loss: 0.2494 - val_accuracy: 0.9249 - val_loss: 0.2020
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8957 - loss: 0.2960 - val_accuracy: 0.9370 - val_loss: 0.1993
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9012 - loss: 0.2652 - val_accuracy: 0.9177 - val_loss: 0.2100
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8974 - loss: 0.3046 - val_accuracy: 0.9249 - val_loss: 0.2239
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.9065 - loss: 0.2395 - val_accuracy: 0.9177 - val_loss: 0.2450
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# =========== Training Run 30/30 ===========
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.8261 - loss: 0.7712 - val_accuracy: 0.8983 - val_loss: 0.2762
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8680 - loss: 0.4353 - val_accuracy: 0.9056 - val_loss: 0.3094
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.8723 - loss: 0.3645 - val_accuracy: 0.9031 - val_loss: 0.2326
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8795 - loss: 0.3349 - val_accuracy: 0.9419 - val_loss: 0.1969
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 0.8746 - loss: 0.3238 - val_accuracy: 0.9249 - val_loss: 0.1997
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8646 - loss: 0.3509 - val_accuracy: 0.9395 - val_loss: 0.1999
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8810 - loss: 0.3086 - val_accuracy: 0.9322 - val_loss: 0.1920
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8934 - loss: 0.2990 - val_accuracy: 0.9249 - val_loss: 0.2215
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8872 - loss: 0.2943 - val_accuracy: 0.9153 - val_loss: 0.2088
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8756 - loss: 0.3190 - val_accuracy: 0.9419 - val_loss: 0.1923
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 262ms/step - accuracy: 0.8903 - loss: 0.3077 - val_accuracy: 0.9298 - val_loss: 0.1878
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 16s 271ms/step - accuracy: 0.8906 - loss: 0.2645 - val_accuracy: 0.9346 - val_loss: 0.1809
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.9062 - loss: 0.2686 - val_accuracy: 0.9370 - val_loss: 0.1761
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9073 - loss: 0.2496 - val_accuracy: 0.9395 - val_loss: 0.1893
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9183 - loss: 0.2328 - val_accuracy: 0.9419 - val_loss: 0.1761
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9102 - loss: 0.2428 - val_accuracy: 0.9564 - val_loss: 0.1787
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.9133 - loss: 0.2274 - val_accuracy: 0.9274 - val_loss: 0.2118
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.9115 - loss: 0.2500 - val_accuracy: 0.9370 - val_loss: 0.1837
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step

# %%
print("\n\n=== Classification Report with Mean±Std ===")

# for class
max_class_length = max(len(str(cls)) for cls in class_names)
print(f"\n{'Class':<{max_class_length}} {'Precision':<6} {'Recall':<6} {'F1-score':<6}  Support")
for idx, cls in enumerate(class_names):
    prec_mean = np.mean(metrics['classes'][cls]['precision'])
    prec_std = np.std(metrics['classes'][cls]['precision'])
    rec_mean = np.mean(metrics['classes'][cls]['recall'])
    rec_std = np.std(metrics['classes'][cls]['recall'])
    f1_mean = np.mean(metrics['classes'][cls]['f1'])
    f1_std = np.std(metrics['classes'][cls]['f1'])
    
    print(f"{idx:<{max_class_length}} "
          f"{prec_mean:.2f}±{prec_std:.2f}  "
          f"{rec_mean:.2f}±{rec_std:.2f}  "
          f"{f1_mean:.2f}±{f1_std:.2f}  "
          f"{test_generator.classes.tolist().count(idx)}")
# for all
def print_avg_row(name, metric_dict):
    prec = f"{np.mean(metric_dict['precision']):.2f}±{np.std(metric_dict['precision']):.2f}"
    rec = f"{np.mean(metric_dict['recall']):.2f}±{np.std(metric_dict['recall']):.2f}"
    f1 = f"{np.mean(metric_dict['f1']):.2f}±{np.std(metric_dict['f1']):.2f}"
    print(f"{name:<{max_class_length}} {prec:<12} {rec:<12} {f1:<12} ")

total_samples = len(test_generator.classes)
print(f"\n{'accuracy':<{max_class_length}} {'':<12} {'':<12} "
      f"{np.mean(metrics['accuracy']):.2f}±{np.std(metrics['accuracy']):.2f}  "
      f"{total_samples}")
print_avg_row('macro avg', metrics['macro_avg'])
print_avg_row('weighted avg', metrics['weighted_avg'])
# Out:
# === Classification Report with Mean±Std ===
#
# Class Precision Recall F1-score  Support
# 0 0.44±0.16  0.36±0.17  0.37±0.12  31
# 1 0.97±0.01  0.98±0.01  0.98±0.00  746
# 2 0.57±0.05  0.57±0.19  0.56±0.12  65
# 3 0.42±0.17  0.37±0.16  0.37±0.15  30
#
# accuracy                           0.91±0.01  872
# macro avg 0.60±0.08    0.57±0.06    0.57±0.07
# weighted avg 0.90±0.02    0.91±0.01    0.90±0.01
